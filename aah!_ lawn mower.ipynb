# %%
f_line = str(input())
s_line = str(input())

#if not ("a" or "h") in (f_line or s_line):
  #quit()

if len(f_line) >= len(s_line):
  print("go")
else:
  print("no")

# %%
end = False
while not end:
  nx, ny, w = list(map(float, input().split()))
  nx = int(nx)
  ny = int(ny)

  if (nx == 0 and ny == 0 and w == 0):
    end = True
    break

  list_x = list(map(float, input().split()))
  list_y = list(map(float, input().split()))

  list_x.sort()
  list_y.sort()
  # list_x.extend([75])
  # list_y.extend([100])

  v_cut = True
  h_cut = True

  for i in range(nx-1):
    if (list_x[i + 1]-list_x[i]) > w:
      v_cut = False
  if(75-list_x[-1]>w/2): 
    v_cut = False
  for i in range(ny-1):
    if (list_y[i + 1]-list_y[i]) > w:
      h_cut = False
  if(100-list_y[-1]>w/2): 
    h_cut = False
  print(v_cut, h_cut)

  if v_cut and h_cut:
    print("YES")
  else:
    print("NO")

# %%
end = False
while not end:
  nx, ny, w = list(map(float, input().split()))
  nx = int(nx)
  ny = int(ny)

  if (nx == 0 and ny == 0 and w == 0):
    end = True
    break

  list_x = list(map(float, input().split()))
  list_y = list(map(float, input().split()))

  list_x.sort()
  list_y.sort()
  # list_x.extend([75])
  # list_y.extend([100])

  v_cut = True
  h_cut = True

  for i in range(nx-1):
    if (list_x[i + 1]-list_x[i]) > w:
      v_cut = False
  for i in range(ny-1):
    if (list_y[i + 1]-list_y[i]) > w:
      h_cut = False
      
  print(v_cut, h_cut)

  if v_cut and h_cut:
    print("YES")
  else:
    print("NO")
